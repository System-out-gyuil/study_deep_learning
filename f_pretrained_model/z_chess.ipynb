# %% [markdown]
# ### 체스 말 분류
# > https://www.kaggle.com/datasets/niteshfre/chessman-image-dataset

# %%
from glob import glob
import os

# 경로 설정
root = './datasets/chess/original/'

# root경로 내의 모든 폴더(*)
directories = glob(os.path.join(root, '*'))
directory_names = []
for directory in directories:
    # 폴더 명을 하나씩 directory_names에 담아줌
    directory_names.append(directory[directory.rindex('\\') + 1:])

print(directory_names)
# Out:
# ['Bishop', 'King', 'Knight', 'Pawn', 'Queen', 'Rook']

# %%
# directory_names에 담긴 이름을 통해 폴더 내의 파일 명을 변경. ex)King01
for name in directory_names:
    for i, file_name in enumerate(os.listdir(os.path.join(root, name))):
        old_file = os.path.join(root + name + '/', file_name)
        new_file = os.path.join(root + name + '/', name + str(i + 1) + '.png')

        os.rename(old_file, new_file)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[2], line 7
#       4 old_file = os.path.join(root + name + '/', file_name)
#       5 new_file = os.path.join(root + name + '/', name + str(i + 1) + '.png')
# ----> 7 os.rename(old_file, new_file)
#
# FileExistsError: [WinError 183] 파일이 이미 있으므로 만들 수 없습니다: './datasets/chess/original/Bishop/Bishop10.png' -> './datasets/chess/original/Bishop/Bishop2.png'

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# 이미지의 모든 픽셀값(0 ~ 255)을 255로 나누어줘서 0 ~ 1값으로 정규화
image_data_generator = ImageDataGenerator(rescale=1./255)

# root경로를 불러오고 target_size를 통해 width와 height를 244 X 244로 조정, 다중 분류이기 때문에 categorical을 통해 원핫 인코딩
generator = image_data_generator.flow_from_directory(root, target_size=(244, 244), batch_size=32, class_mode='categorical')
print(generator.class_indices)
# Out:
# Found 556 images belonging to 6 classes.
# {'Bishop': 0, 'King': 1, 'Knight': 2, 'Pawn': 3, 'Queen': 4, 'Rook': 5}

# %%
import pandas as pd

# 파일 내의 각 사진의 경로와 인코딩 된 타겟을 DataFrame으로 만들어
c_df = pd.DataFrame({'file_paths': generator.filepaths, 'targets': generator.classes})
c_df
# Out:
#                                         file_paths  targets
# 0     ./datasets/chess/original/Bishop\Bishop1.png        0
# 1    ./datasets/chess/original/Bishop\Bishop10.png        0
# 2    ./datasets/chess/original/Bishop\Bishop11.png        0
# 3    ./datasets/chess/original/Bishop\Bishop12.png        0
# 4    ./datasets/chess/original/Bishop\Bishop13.png        0
# ..                                             ...      ...
# 551      ./datasets/chess/original/Rook\Rook95.png        5
# 552      ./datasets/chess/original/Rook\Rook96.png        5
# 553      ./datasets/chess/original/Rook\Rook97.png        5
# 554      ./datasets/chess/original/Rook\Rook98.png        5
# 555      ./datasets/chess/original/Rook\Rook99.png        5
#
# [556 rows x 2 columns]

# %%
# file_paths 피쳐에 \로 된 부분을 /로 변경
c_df.loc[:, 'file_paths'] = c_df.file_paths.apply(lambda x: x.replace('\\', '/'))
c_df
# Out:
#                                         file_paths  targets
# 0     ./datasets/chess/original/Bishop/Bishop1.png        0
# 1    ./datasets/chess/original/Bishop/Bishop10.png        0
# 2    ./datasets/chess/original/Bishop/Bishop11.png        0
# 3    ./datasets/chess/original/Bishop/Bishop12.png        0
# 4    ./datasets/chess/original/Bishop/Bishop13.png        0
# ..                                             ...      ...
# 551      ./datasets/chess/original/Rook/Rook95.png        5
# 552      ./datasets/chess/original/Rook/Rook96.png        5
# 553      ./datasets/chess/original/Rook/Rook97.png        5
# 554      ./datasets/chess/original/Rook/Rook98.png        5
# 555      ./datasets/chess/original/Rook/Rook99.png        5
#
# [556 rows x 2 columns]

# %%
# 타겟 비중 확인
c_df.targets.value_counts()
# Out:
# targets
# 3    107
# 2    106
# 5    102
# 0     87
# 4     78
# 1     76
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# c_df에서 train데이터와 test데이터 분리
X_train, X_test, y_train, y_test = \
train_test_split(c_df.file_paths, c_df.targets, stratify=c_df.targets, test_size=0.2, random_state=124)

# 위에서 분리한 train데이터에서 validation 데이터 분리
X_train, X_val, y_train, y_val = \
train_test_split(X_train, y_train, stratify=y_train, test_size=0.2, random_state=124)

print(y_train.value_counts())
print(y_val.value_counts())
print(y_test.value_counts())
# Out:
# targets
# 2    68
# 3    68
# 5    65
# 0    56
# 4    49
# 1    49
# Name: count, dtype: int64
# targets
# 3    17
# 2    17
# 5    16
# 0    14
# 4    13
# 1    12
# Name: count, dtype: int64
# targets
# 3    22
# 5    21
# 2    21
# 0    17
# 4    16
# 1    15
# Name: count, dtype: int64

# %%
import shutil

# chess파일 경로
chess_root = './datasets/chess/'

# train데이터를 train폴더를 만들어 저장
for file_path in X_train:
    chess_dir = file_path[len(chess_root + 'original/'): file_path.rindex('/')]
    destination = os.path.join(chess_root, 'train/' + chess_dir)

    # 해당 경로에 destination경로가 없다면 생성
    if not os.path.exists(destination):
        os.makedirs(destination)

    shutil.copy2(file_path, destination)

# %%
# validation
for file_path in X_val:
    chess_dir = file_path[len(chess_root + 'original/'): file_path.rindex('/')]
    destination = os.path.join(chess_root, 'validation/' + chess_dir)

    if not os.path.exists(destination):
        os.makedirs(destination)

    shutil.copy2(file_path, destination)

# %%
# test
for file_path in X_test:
    chess_dir = file_path[len(chess_root + 'original/'): file_path.rindex('/')]
    destination = os.path.join(chess_root, 'test/' + chess_dir)

    if not os.path.exists(destination):
        os.makedirs(destination)

    shutil.copy2(file_path, destination)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

IMAGE_SIZE = 100

train_dir = './datasets/chess/train'
validation_dir = './datasets/chess/validation'
test_dir = './datasets/chess/test'

train_data_generator = ImageDataGenerator(rescale=1./255)
validation_data_generator = ImageDataGenerator(rescale=1./255)
test_data_generator = ImageDataGenerator(rescale=1./255)

train_generator = train_data_generator.flow_from_directory(
    train_dir,
    target_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=16,
    class_mode='categorical'
)

validation_generator = validation_data_generator.flow_from_directory(
    validation_dir,
    target_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=16,
    class_mode='categorical'
)

test_generator = test_data_generator.flow_from_directory(
    test_dir,
    target_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=16,
    class_mode='categorical'
)

print(train_generator.class_indices)
print(validation_generator.class_indices)
print(test_generator.class_indices)
# Out:
# Found 355 images belonging to 6 classes.
# Found 89 images belonging to 6 classes.
# Found 112 images belonging to 6 classes.
# {'Bishop': 0, 'King': 1, 'Knight': 2, 'Pawn': 3, 'Queen': 4, 'Rook': 5}
# {'Bishop': 0, 'King': 1, 'Knight': 2, 'Pawn': 3, 'Queen': 4, 'Rook': 5}
# {'Bishop': 0, 'King': 1, 'Knight': 2, 'Pawn': 3, 'Queen': 4, 'Rook': 5}

# %%
target_name = {v: k for k, v in train_generator.class_indices.items()}
target_name
# Out:
# {0: 'Bishop', 1: 'King', 2: 'Knight', 3: 'Pawn', 4: 'Queen', 5: 'Rook'}

# %%
train_target_names = []
for target in train_generator.classes:
    train_target_names.append(target_name[target])

valid_target_names = []
for target in validation_generator.classes:
    valid_target_names.append(target_name[target])

test_target_names = []
for target in test_generator.classes:
    test_target_names.append(target_name[target])

# %%
import pandas as pd

train_df = pd.DataFrame({'file_paths': train_generator.filepaths, 'target_names': train_target_names, 'targets': train_generator.classes})
train_df.file_paths = train_df.file_paths.apply(lambda file_path: file_path.replace('\\', '/'))

validation_df = pd.DataFrame({'file_paths': validation_generator.filepaths, 'target_names': valid_target_names, 'targets': validation_generator.classes})
validation_df.file_paths = validation_df.file_paths.apply(lambda file_path: file_path.replace('\\', '/')) 

test_df = pd.DataFrame({'file_paths': test_generator.filepaths, 'target_names': test_target_names, 'targets': test_generator.classes})
test_df.file_paths = test_df.file_paths.apply(lambda file_path: file_path.replace('\\', '/'))

train_df
# Out:
#                                      file_paths target_names  targets
# 0     ./datasets/chess/train/Bishop/Bishop1.png       Bishop        0
# 1    ./datasets/chess/train/Bishop/Bishop10.png       Bishop        0
# 2    ./datasets/chess/train/Bishop/Bishop11.png       Bishop        0
# 3    ./datasets/chess/train/Bishop/Bishop12.png       Bishop        0
# 4    ./datasets/chess/train/Bishop/Bishop13.png       Bishop        0
# ..                                          ...          ...      ...
# 350      ./datasets/chess/train/Rook/Rook92.png         Rook        5
# 351      ./datasets/chess/train/Rook/Rook93.png         Rook        5
# 352      ./datasets/chess/train/Rook/Rook95.png         Rook        5
# 353      ./datasets/chess/train/Rook/Rook97.png         Rook        5
# 354      ./datasets/chess/train/Rook/Rook98.png         Rook        5
#
# [355 rows x 3 columns]

# %%
print(train_df.shape)
print(validation_df.shape)
print(test_df.shape)
# Out:
# (355, 3)
# (89, 3)
# (112, 3)

# %%
import numpy as np
from tensorflow.keras.utils import Sequence
from sklearn.utils import shuffle
import cv2

IMAGE_SIZE = 100
BATCH_SIZE = 16

class Dataset(Sequence):
    def __init__(self, file_paths, targets, batch_size=BATCH_SIZE, aug=None, preprocess=None, shuffle=False):
        self.file_paths = file_paths
        self.targets = targets
        self.batch_size = batch_size
        self.aug = aug
        self.preprocess = preprocess
        self.shuffle = shuffle

        if self.shuffle:
            # 에포크 종료 시, 객체 생성 및 데이터 섞기
            self.on_epoch_end()

    # __len__()는 전체 데이터 건수에서 batch_size 단위로 나눈 데이터 수
    # 예를 들어, 1000개의 데이터를 30 batch_size로 설정하면, 1 batch당 33.33..개이다.
    # 이 때, 소수점은 무조건 올려서 33 + 1 = 34개로 설정한다.
    def __len__(self):
        return int(np.ceil(len(self.targets) / self.batch_size))

    # batch_size 단위로 이미지 배열과 타켓 데이터들을 가져온 뒤 변환한 값을 리턴한다.
    def __getitem__(self, index):
        file_paths_batch = self.file_paths[index * self.batch_size: (index + 1) * self.batch_size]
        targets_batch = self.targets[index * self.batch_size: (index + 1) * self.batch_size]

        results_batch = np.zeros((file_paths_batch.shape[0], IMAGE_SIZE, IMAGE_SIZE, 3))

        for i in range(file_paths_batch.shape[0]):
            print(file_paths_batch[i])
            image = cv2.cvtColor(cv2.imread(file_paths_batch[i]), cv2.COLOR_BGR2RGB)
            image = cv2.resize(image, (IMAGE_SIZE, IMAGE_SIZE))

            if self.aug is not None:
                image = self.aug(image=image)['image']

            if self.preprocess is not None:
                image = self.preprocess(image)
                    
            results_batch[i] = image

        return results_batch, targets_batch
        
    def on_epoch_end(self):
        if self.shuffle:
            self.file_paths, self.targets = shuffle(self.file_paths, self.targets)

# %%
import albumentations as A
from tensorflow.keras.applications.xception import preprocess_input as xception_preprocess_input

# train 데이터의 파일 경로를 리스트로 담아줌
train_file_paths = train_df['file_paths'].values
# target을 get_dummies를 통해 원핫인코딩
train_targets = pd.get_dummies(train_df['targets']).values

validation_file_paths = validation_df['file_paths'].values
validation_targets = pd.get_dummies(validation_df['targets']).values

test_file_paths = test_df['file_paths'].values
test_targets = pd.get_dummies(test_df['targets']).values

# aug = A.Compose([
#     A.VerticalFlip(p=0.5),
#     A.HorizontalFlip(p=0.5)
# ])

train_dataset = Dataset(train_file_paths, 
                        train_targets, 
                        batch_size=BATCH_SIZE,
                        preprocess=xception_preprocess_input, 
                        shuffle=True)

validation_dataset = Dataset(validation_file_paths, 
                        validation_targets, 
                        batch_size=BATCH_SIZE, 
                        preprocess=xception_preprocess_input)

test_dataset = Dataset(test_file_paths, 
                        test_targets, 
                        batch_size=BATCH_SIZE, 
                        preprocess=xception_preprocess_input)

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense , Conv2D , Dropout , Flatten , Activation, MaxPooling2D , GlobalAveragePooling2D
from tensorflow.keras.layers import BatchNormalization

from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications import ResNet50V2
from tensorflow.keras.applications import Xception
from tensorflow.keras.applications import MobileNetV2

def create_model(model_name='vgg16', verbose=False):
    input_tensor = Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 3))
    if model_name == 'vgg16':
        model = VGG16(input_tensor=input_tensor, include_top=False, weights='imagenet')
    elif model_name == 'resnet50': # ResNet50, 74.9% ; ResNet50V2, 76.0%
        model = ResNet50V2(input_tensor=input_tensor, include_top=False, weights='imagenet')
    elif model_name == 'xception': # Inception을 기초로 한 모델
        model = Xception(input_tensor=input_tensor, include_top=False, weights='imagenet')
    elif model_name == 'mobilenet':
        model = MobileNetV2(input_tensor=input_tensor, include_top=False, weights='imagenet')

    x = model.output

    # 분류기
    x = GlobalAveragePooling2D()(x)
    if model_name != 'vgg16':
        x = Dropout(rate=0.5)(x)
    x = Dense(50, activation='relu')(x)
    if model_name != 'vgg16':
        x = Dropout(rate=0.5)(x)
    output = Dense(6, activation='softmax', name='output')(x)
    
    model = Model(inputs=input_tensor, outputs=output)
    
    if verbose:
        model.summary()
    
    return model

# %%
from tensorflow.keras.losses import SparseCategoricalCrossentropy, CategoricalCrossentropy
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Accuracy

model = create_model(model_name='xception', verbose=True)
# model.compile(optimizer=Adam(), loss=SparseCategoricalCrossentropy(), metrics=['acc'])
model.compile(optimizer=Adam(), loss=CategoricalCrossentropy(), metrics=['acc'])
# Out:
# Model: "functional_21"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_10 (InputLayer)   │ (None, 100, 100, 3)       │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block1_conv1 (Conv2D)         │ (None, 49, 49, 32)        │             864 │ input_layer_10[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block1_conv1_bn               │ (None, 49, 49, 32)        │             128 │ block1_conv1[0][0]         │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block1_conv1_act (Activation) │ (None, 49, 49, 32)        │               0 │ block1_conv1_bn[0][0]      │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block1_conv2 (Conv2D)         │ (None, 47, 47, 64)        │          18,432 │ block1_conv1_act[0][0]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block1_conv2_bn               │ (None, 47, 47, 64)        │             256 │ block1_conv2[0][0]         │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block1_conv2_act (Activation) │ (None, 47, 47, 64)        │               0 │ block1_conv2_bn[0][0]      │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block2_sepconv1               │ (None, 47, 47, 128)       │           8,768 │ block1_conv2_act[0][0]     │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block2_sepconv1_bn            │ (None, 47, 47, 128)       │             512 │ block2_sepconv1[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block2_sepconv2_act           │ (None, 47, 47, 128)       │               0 │ block2_sepconv1_bn[0][0]   │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block2_sepconv2               │ (None, 47, 47, 128)       │          17,536 │ block2_sepconv2_act[0][0]  │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block2_sepconv2_bn            │ (None, 47, 47, 128)       │             512 │ block2_sepconv2[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_40 (Conv2D)            │ (None, 24, 24, 128)       │           8,192 │ block1_conv2_act[0][0]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block2_pool (MaxPooling2D)    │ (None, 24, 24, 128)       │               0 │ block2_sepconv2_bn[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_40        │ (None, 24, 24, 128)       │             512 │ conv2d_40[0][0]            │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_120 (Add)                 │ (None, 24, 24, 128)       │               0 │ block2_pool[0][0],         │
# │                               │                           │                 │ batch_normalization_40[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block3_sepconv1_act           │ (None, 24, 24, 128)       │               0 │ add_120[0][0]              │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block3_sepconv1               │ (None, 24, 24, 256)       │          33,920 │ block3_sepconv1_act[0][0]  │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block3_sepconv1_bn            │ (None, 24, 24, 256)       │           1,024 │ block3_sepconv1[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block3_sepconv2_act           │ (None, 24, 24, 256)       │               0 │ block3_sepconv1_bn[0][0]   │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block3_sepconv2               │ (None, 24, 24, 256)       │          67,840 │ block3_sepconv2_act[0][0]  │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block3_sepconv2_bn            │ (None, 24, 24, 256)       │           1,024 │ block3_sepconv2[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_41 (Conv2D)            │ (None, 12, 12, 256)       │          32,768 │ add_120[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block3_pool (MaxPooling2D)    │ (None, 12, 12, 256)       │               0 │ block3_sepconv2_bn[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_41        │ (None, 12, 12, 256)       │           1,024 │ conv2d_41[0][0]            │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_121 (Add)                 │ (None, 12, 12, 256)       │               0 │ block3_pool[0][0],         │
# │                               │                           │                 │ batch_normalization_41[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4_sepconv1_act           │ (None, 12, 12, 256)       │               0 │ add_121[0][0]              │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4_sepconv1               │ (None, 12, 12, 728)       │         188,672 │ block4_sepconv1_act[0][0]  │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4_sepconv1_bn            │ (None, 12, 12, 728)       │           2,912 │ block4_sepconv1[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4_sepconv2_act           │ (None, 12, 12, 728)       │               0 │ block4_sepconv1_bn[0][0]   │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4_sepconv2               │ (None, 12, 12, 728)       │         536,536 │ block4_sepconv2_act[0][0]  │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4_sepconv2_bn            │ (None, 12, 12, 728)       │           2,912 │ block4_sepconv2[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_42 (Conv2D)            │ (None, 6, 6, 728)         │         186,368 │ add_121[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block4_pool (MaxPooling2D)    │ (None, 6, 6, 728)         │               0 │ block4_sepconv2_bn[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_42        │ (None, 6, 6, 728)         │           2,912 │ conv2d_42[0][0]            │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_122 (Add)                 │ (None, 6, 6, 728)         │               0 │ block4_pool[0][0],         │
# │                               │                           │                 │ batch_normalization_42[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5_sepconv1_act           │ (None, 6, 6, 728)         │               0 │ add_122[0][0]              │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5_sepconv1               │ (None, 6, 6, 728)         │         536,536 │ block5_sepconv1_act[0][0]  │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5_sepconv1_bn            │ (None, 6, 6, 728)         │           2,912 │ block5_sepconv1[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5_sepconv2_act           │ (None, 6, 6, 728)         │               0 │ block5_sepconv1_bn[0][0]   │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5_sepconv2               │ (None, 6, 6, 728)         │         536,536 │ block5_sepconv2_act[0][0]  │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5_sepconv2_bn            │ (None, 6, 6, 728)         │           2,912 │ block5_sepconv2[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5_sepconv3_act           │ (None, 6, 6, 728)         │               0 │ block5_sepconv2_bn[0][0]   │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5_sepconv3               │ (None, 6, 6, 728)         │         536,536 │ block5_sepconv3_act[0][0]  │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block5_sepconv3_bn            │ (None, 6, 6, 728)         │           2,912 │ block5_sepconv3[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_123 (Add)                 │ (None, 6, 6, 728)         │               0 │ block5_sepconv3_bn[0][0],  │
# │                               │                           │                 │ add_122[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6_sepconv1_act           │ (None, 6, 6, 728)         │               0 │ add_123[0][0]              │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6_sepconv1               │ (None, 6, 6, 728)         │         536,536 │ block6_sepconv1_act[0][0]  │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6_sepconv1_bn            │ (None, 6, 6, 728)         │           2,912 │ block6_sepconv1[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6_sepconv2_act           │ (None, 6, 6, 728)         │               0 │ block6_sepconv1_bn[0][0]   │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6_sepconv2               │ (None, 6, 6, 728)         │         536,536 │ block6_sepconv2_act[0][0]  │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6_sepconv2_bn            │ (None, 6, 6, 728)         │           2,912 │ block6_sepconv2[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6_sepconv3_act           │ (None, 6, 6, 728)         │               0 │ block6_sepconv2_bn[0][0]   │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6_sepconv3               │ (None, 6, 6, 728)         │         536,536 │ block6_sepconv3_act[0][0]  │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block6_sepconv3_bn            │ (None, 6, 6, 728)         │           2,912 │ block6_sepconv3[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_124 (Add)                 │ (None, 6, 6, 728)         │               0 │ block6_sepconv3_bn[0][0],  │
# │                               │                           │                 │ add_123[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block7_sepconv1_act           │ (None, 6, 6, 728)         │               0 │ add_124[0][0]              │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block7_sepconv1               │ (None, 6, 6, 728)         │         536,536 │ block7_sepconv1_act[0][0]  │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block7_sepconv1_bn            │ (None, 6, 6, 728)         │           2,912 │ block7_sepconv1[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block7_sepconv2_act           │ (None, 6, 6, 728)         │               0 │ block7_sepconv1_bn[0][0]   │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block7_sepconv2               │ (None, 6, 6, 728)         │         536,536 │ block7_sepconv2_act[0][0]  │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block7_sepconv2_bn            │ (None, 6, 6, 728)         │           2,912 │ block7_sepconv2[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block7_sepconv3_act           │ (None, 6, 6, 728)         │               0 │ block7_sepconv2_bn[0][0]   │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block7_sepconv3               │ (None, 6, 6, 728)         │         536,536 │ block7_sepconv3_act[0][0]  │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block7_sepconv3_bn            │ (None, 6, 6, 728)         │           2,912 │ block7_sepconv3[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_125 (Add)                 │ (None, 6, 6, 728)         │               0 │ block7_sepconv3_bn[0][0],  │
# │                               │                           │                 │ add_124[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block8_sepconv1_act           │ (None, 6, 6, 728)         │               0 │ add_125[0][0]              │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block8_sepconv1               │ (None, 6, 6, 728)         │         536,536 │ block8_sepconv1_act[0][0]  │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block8_sepconv1_bn            │ (None, 6, 6, 728)         │           2,912 │ block8_sepconv1[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block8_sepconv2_act           │ (None, 6, 6, 728)         │               0 │ block8_sepconv1_bn[0][0]   │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block8_sepconv2               │ (None, 6, 6, 728)         │         536,536 │ block8_sepconv2_act[0][0]  │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block8_sepconv2_bn            │ (None, 6, 6, 728)         │           2,912 │ block8_sepconv2[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block8_sepconv3_act           │ (None, 6, 6, 728)         │               0 │ block8_sepconv2_bn[0][0]   │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block8_sepconv3               │ (None, 6, 6, 728)         │         536,536 │ block8_sepconv3_act[0][0]  │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block8_sepconv3_bn            │ (None, 6, 6, 728)         │           2,912 │ block8_sepconv3[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_126 (Add)                 │ (None, 6, 6, 728)         │               0 │ block8_sepconv3_bn[0][0],  │
# │                               │                           │                 │ add_125[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block9_sepconv1_act           │ (None, 6, 6, 728)         │               0 │ add_126[0][0]              │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block9_sepconv1               │ (None, 6, 6, 728)         │         536,536 │ block9_sepconv1_act[0][0]  │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block9_sepconv1_bn            │ (None, 6, 6, 728)         │           2,912 │ block9_sepconv1[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block9_sepconv2_act           │ (None, 6, 6, 728)         │               0 │ block9_sepconv1_bn[0][0]   │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block9_sepconv2               │ (None, 6, 6, 728)         │         536,536 │ block9_sepconv2_act[0][0]  │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block9_sepconv2_bn            │ (None, 6, 6, 728)         │           2,912 │ block9_sepconv2[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block9_sepconv3_act           │ (None, 6, 6, 728)         │               0 │ block9_sepconv2_bn[0][0]   │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block9_sepconv3               │ (None, 6, 6, 728)         │         536,536 │ block9_sepconv3_act[0][0]  │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block9_sepconv3_bn            │ (None, 6, 6, 728)         │           2,912 │ block9_sepconv3[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_127 (Add)                 │ (None, 6, 6, 728)         │               0 │ block9_sepconv3_bn[0][0],  │
# │                               │                           │                 │ add_126[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block10_sepconv1_act          │ (None, 6, 6, 728)         │               0 │ add_127[0][0]              │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block10_sepconv1              │ (None, 6, 6, 728)         │         536,536 │ block10_sepconv1_act[0][0] │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block10_sepconv1_bn           │ (None, 6, 6, 728)         │           2,912 │ block10_sepconv1[0][0]     │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block10_sepconv2_act          │ (None, 6, 6, 728)         │               0 │ block10_sepconv1_bn[0][0]  │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block10_sepconv2              │ (None, 6, 6, 728)         │         536,536 │ block10_sepconv2_act[0][0] │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block10_sepconv2_bn           │ (None, 6, 6, 728)         │           2,912 │ block10_sepconv2[0][0]     │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block10_sepconv3_act          │ (None, 6, 6, 728)         │               0 │ block10_sepconv2_bn[0][0]  │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block10_sepconv3              │ (None, 6, 6, 728)         │         536,536 │ block10_sepconv3_act[0][0] │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block10_sepconv3_bn           │ (None, 6, 6, 728)         │           2,912 │ block10_sepconv3[0][0]     │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_128 (Add)                 │ (None, 6, 6, 728)         │               0 │ block10_sepconv3_bn[0][0], │
# │                               │                           │                 │ add_127[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block11_sepconv1_act          │ (None, 6, 6, 728)         │               0 │ add_128[0][0]              │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block11_sepconv1              │ (None, 6, 6, 728)         │         536,536 │ block11_sepconv1_act[0][0] │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block11_sepconv1_bn           │ (None, 6, 6, 728)         │           2,912 │ block11_sepconv1[0][0]     │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block11_sepconv2_act          │ (None, 6, 6, 728)         │               0 │ block11_sepconv1_bn[0][0]  │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block11_sepconv2              │ (None, 6, 6, 728)         │         536,536 │ block11_sepconv2_act[0][0] │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block11_sepconv2_bn           │ (None, 6, 6, 728)         │           2,912 │ block11_sepconv2[0][0]     │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block11_sepconv3_act          │ (None, 6, 6, 728)         │               0 │ block11_sepconv2_bn[0][0]  │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block11_sepconv3              │ (None, 6, 6, 728)         │         536,536 │ block11_sepconv3_act[0][0] │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block11_sepconv3_bn           │ (None, 6, 6, 728)         │           2,912 │ block11_sepconv3[0][0]     │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_129 (Add)                 │ (None, 6, 6, 728)         │               0 │ block11_sepconv3_bn[0][0], │
# │                               │                           │                 │ add_128[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block12_sepconv1_act          │ (None, 6, 6, 728)         │               0 │ add_129[0][0]              │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block12_sepconv1              │ (None, 6, 6, 728)         │         536,536 │ block12_sepconv1_act[0][0] │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block12_sepconv1_bn           │ (None, 6, 6, 728)         │           2,912 │ block12_sepconv1[0][0]     │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block12_sepconv2_act          │ (None, 6, 6, 728)         │               0 │ block12_sepconv1_bn[0][0]  │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block12_sepconv2              │ (None, 6, 6, 728)         │         536,536 │ block12_sepconv2_act[0][0] │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block12_sepconv2_bn           │ (None, 6, 6, 728)         │           2,912 │ block12_sepconv2[0][0]     │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block12_sepconv3_act          │ (None, 6, 6, 728)         │               0 │ block12_sepconv2_bn[0][0]  │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block12_sepconv3              │ (None, 6, 6, 728)         │         536,536 │ block12_sepconv3_act[0][0] │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block12_sepconv3_bn           │ (None, 6, 6, 728)         │           2,912 │ block12_sepconv3[0][0]     │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_130 (Add)                 │ (None, 6, 6, 728)         │               0 │ block12_sepconv3_bn[0][0], │
# │                               │                           │                 │ add_129[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block13_sepconv1_act          │ (None, 6, 6, 728)         │               0 │ add_130[0][0]              │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block13_sepconv1              │ (None, 6, 6, 728)         │         536,536 │ block13_sepconv1_act[0][0] │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block13_sepconv1_bn           │ (None, 6, 6, 728)         │           2,912 │ block13_sepconv1[0][0]     │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block13_sepconv2_act          │ (None, 6, 6, 728)         │               0 │ block13_sepconv1_bn[0][0]  │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block13_sepconv2              │ (None, 6, 6, 1024)        │         752,024 │ block13_sepconv2_act[0][0] │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block13_sepconv2_bn           │ (None, 6, 6, 1024)        │           4,096 │ block13_sepconv2[0][0]     │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_43 (Conv2D)            │ (None, 3, 3, 1024)        │         745,472 │ add_130[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block13_pool (MaxPooling2D)   │ (None, 3, 3, 1024)        │               0 │ block13_sepconv2_bn[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_43        │ (None, 3, 3, 1024)        │           4,096 │ conv2d_43[0][0]            │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_131 (Add)                 │ (None, 3, 3, 1024)        │               0 │ block13_pool[0][0],        │
# │                               │                           │                 │ batch_normalization_43[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block14_sepconv1              │ (None, 3, 3, 1536)        │       1,582,080 │ add_131[0][0]              │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block14_sepconv1_bn           │ (None, 3, 3, 1536)        │           6,144 │ block14_sepconv1[0][0]     │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block14_sepconv1_act          │ (None, 3, 3, 1536)        │               0 │ block14_sepconv1_bn[0][0]  │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block14_sepconv2              │ (None, 3, 3, 2048)        │       3,159,552 │ block14_sepconv1_act[0][0] │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block14_sepconv2_bn           │ (None, 3, 3, 2048)        │           8,192 │ block14_sepconv2[0][0]     │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block14_sepconv2_act          │ (None, 3, 3, 2048)        │               0 │ block14_sepconv2_bn[0][0]  │
# │ (Activation)                  │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ global_average_pooling2d_10   │ (None, 2048)              │               0 │ block14_sepconv2_act[0][0] │
# │ (GlobalAveragePooling2D)      │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_20 (Dropout)          │ (None, 2048)              │               0 │ global_average_pooling2d_… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_10 (Dense)              │ (None, 50)                │         102,450 │ dropout_20[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_21 (Dropout)          │ (None, 50)                │               0 │ dense_10[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ output (Dense)                │ (None, 6)                 │             306 │ dropout_21[0][0]           │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 20,964,236 (79.97 MB)
#  Trainable params: 20,909,708 (79.76 MB)
#  Non-trainable params: 54,528 (213.00 KB)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping

mcp_cb = ModelCheckpoint(
    filepath="./callback_files/weights.{epoch:03d}-{val_loss:.4f}-{acc:.4f}.weights.h5",
    monitor='val_loss',
    save_best_only=False,
    save_weights_only=True,
    mode='min'
)

rlr_cb = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.1,
    patience=2,
    mode='min'
)

ely_cb = EarlyStopping(
    monitor='val_loss',
    patience=5,
    mode='min'
)

# %%
N_EPOCHS = 20
BATCH_SIZE = 16

history = model.fit(train_dataset,
                    batch_size=BATCH_SIZE,
                    epochs=N_EPOCHS, 
                    validation_data=validation_dataset,
                    callbacks=[mcp_cb, rlr_cb, ely_cb])
# Out:
# ./datasets/chess/train/Knight/Knight67.png
# ./datasets/chess/train/Rook/Rook52.png
# ./datasets/chess/train/Bishop/Bishop72.png
# ./datasets/chess/train/Pawn/Pawn81.png
# ./datasets/chess/train/Knight/Knight2.png
# ./datasets/chess/train/Queen/Queen78.png
# ./datasets/chess/train/Pawn/Pawn25.png
# ./datasets/chess/train/King/King19.png
# ./datasets/chess/train/Knight/Knight97.png
# ./datasets/chess/train/Rook/Rook21.png
# ./datasets/chess/train/Pawn/Pawn89.png
# ./datasets/chess/train/Bishop/Bishop81.png
# ./datasets/chess/train/King/King22.png
# ./datasets/chess/train/Knight/Knight65.png
# ./datasets/chess/train/Rook/Rook15.png
# ./datasets/chess/train/Bishop/Bishop52.png
# ./datasets/chess/train/Queen/Queen39.png
# ./datasets/chess/train/Knight/Knight66.png
# ./datasets/chess/train/Bishop/Bishop70.png
# ./datasets/chess/train/Knight/Knight88.png
# ./datasets/chess/train/Rook/Rook28.png
# ./datasets/chess/train/Bishop/Bishop22.png
# ./datasets/chess/train/Knight/Knight95.png
# ./datasets/chess/train/King/King72.png
# ./datasets/chess/train/Pawn/Pawn82.png
# ./datasets/chess/train/Knight/Knight43.png
# ./datasets/chess/train/Rook/Rook30.png
# ./datasets/chess/train/Queen/Queen9.png
# ./datasets/chess/train/Pawn/Pawn50.png
# ./datasets/chess/train/Knight/Knight63.png
# ./datasets/chess/train/Knight/Knight80.png
# ./datasets/chess/train/Pawn/Pawn20.png
# Epoch 1/20
# ./datasets/chess/train/Knight/Knight35.png
# ./datasets/chess/train/Rook/Rook58.png
# ./datasets/chess/train/Bishop/Bishop77.png
# ./datasets/chess/train/Pawn/Pawn95.png
# ./datasets/chess/train/Bishop/Bishop85.png
# ./datasets/chess/train/Knight/Knight87.png
# ./datasets/chess/train/Rook/Rook32.png
# ./datasets/chess/train/Pawn/Pawn29.png
# ./datasets/chess/train/Knight/Knight100.png
# ./datasets/chess/train/Queen/Queen49.png
# ./datasets/chess/train/Knight/Knight46.png
# ./datasets/chess/train/Rook/Rook83.png
# ./datasets/chess/train/Rook/Rook29.png
# ./datasets/chess/train/Pawn/Pawn61.png
# ./datasets/chess/train/Rook/Rook90.png
# ./datasets/chess/train/Knight/Knight4.png
# ./datasets/chess/train/Pawn/Pawn4.png
# ./datasets/chess/train/Pawn/Pawn9.png
# ./datasets/chess/train/Bishop/Bishop5.png
# ./datasets/chess/train/Rook/Rook33.png
# ./datasets/chess/train/Pawn/Pawn94.png
# ./datasets/chess/train/Pawn/Pawn99.png
# ./datasets/chess/train/Knight/Knight40.png
# ./datasets/chess/train/Knight/Knight99.png
# ./datasets/chess/train/Queen/Queen1.png
# ./datasets/chess/train/Bishop/Bishop56.png
# ./datasets/chess/train/Queen/Queen63.png
# ./datasets/chess/train/Pawn/Pawn90.png
# ./datasets/chess/train/Pawn/Pawn87.png
# ./datasets/chess/train/King/King60.png
# ./datasets/chess/train/Bishop/Bishop57.png
# ./datasets/chess/train/King/King21.png
# ./datasets/chess/train/Pawn/Pawn65.png
# ./datasets/chess/train/Rook/Rook79.png
# ./datasets/chess/train/Rook/Rook51.png
# ./datasets/chess/train/Pawn/Pawn28.png
# ./datasets/chess/train/Bishop/Bishop41.png
# ./datasets/chess/train/Pawn/Pawn10.png
# ./datasets/chess/train/Knight/Knight51.png
# ./datasets/chess/train/Knight/Knight1.png
# ./datasets/chess/train/Bishop/Bishop59.png
# ./datasets/chess/train/Knight/Knight30.png
# ./datasets/chess/train/Pawn/Pawn102.png
# ./datasets/chess/train/King/King25.png
# ./datasets/chess/train/Knight/Knight32.png
# ./datasets/chess/train/Pawn/Pawn11.png
# ./datasets/chess/train/Knight/Knight18.png
# ./datasets/chess/train/Rook/Rook82.png
# ./datasets/chess/train/Knight/Knight14.png
# ./datasets/chess/train/Knight/Knight72.png
# ./datasets/chess/train/Bishop/Bishop44.png
# ./datasets/chess/train/Bishop/Bishop50.png
# ./datasets/chess/train/Queen/Queen54.png
# ./datasets/chess/train/Pawn/Pawn100.png
# ./datasets/chess/train/Rook/Rook41.png
# ./datasets/chess/train/Knight/Knight69.png
# ./datasets/chess/train/Pawn/Pawn96.png
# ./datasets/chess/train/Queen/Queen64.png
# ./datasets/chess/train/Knight/Knight55.png
# ./datasets/chess/train/King/King12.png
# ./datasets/chess/train/King/King6.png
# ./datasets/chess/train/Pawn/Pawn51.png
# ./datasets/chess/train/Queen/Queen16.png
# ./datasets/chess/train/Pawn/Pawn38.png
# ./datasets/chess/train/King/King63.png
# ./datasets/chess/train/Rook/Rook64.png
# ./datasets/chess/train/Rook/Rook48.png
# ./datasets/chess/train/Rook/Rook53.png
# ./datasets/chess/train/Rook/Rook80.png
# ./datasets/chess/train/Pawn/Pawn75.png
# ./datasets/chess/train/Queen/Queen10.png
# ./datasets/chess/train/King/King75.png
# ./datasets/chess/train/Knight/Knight81.png
# ./datasets/chess/train/Queen/Queen26.png
# ./datasets/chess/train/Pawn/Pawn23.png
# ./datasets/chess/train/King/King28.png
# ./datasets/chess/train/Rook/Rook49.png
# ./datasets/chess/train/Rook/Rook89.png
# ./datasets/chess/train/Queen/Queen28.png
# ./datasets/chess/train/Pawn/Pawn56.png
# ./datasets/chess/train/Bishop/Bishop55.png
# ./datasets/chess/train/Rook/Rook23.png
# ./datasets/chess/train/Bishop/Bishop65.png
# ./datasets/chess/train/Rook/Rook72.png
# ./datasets/chess/train/Knight/Knight102.png
# ./datasets/chess/train/Knight/Knight101.png
# ./datasets/chess/train/Knight/Knight71.png
# ./datasets/chess/train/Queen/Queen42.png
# ./datasets/chess/train/Rook/Rook25.png
# ./datasets/chess/train/Bishop/Bishop48.png
# ./datasets/chess/train/Bishop/Bishop19.png
# ./datasets/chess/train/King/King52.png
# ./datasets/chess/train/Pawn/Pawn48.png
# ./datasets/chess/train/Knight/Knight94.png
# ./datasets/chess/train/Rook/Rook24.png
# ./datasets/chess/train/Pawn/Pawn42.png
# ./datasets/chess/train/Knight/Knight105.png
# ./datasets/chess/train/Knight/Knight85.png
# ./datasets/chess/train/Knight/Knight38.png
# ./datasets/chess/train/Rook/Rook92.png
# ./datasets/chess/train/Queen/Queen69.png
# ./datasets/chess/train/Rook/Rook31.png
# ./datasets/chess/train/Bishop/Bishop69.png
# ./datasets/chess/train/Rook/Rook85.png
# ./datasets/chess/train/Knight/Knight27.png
# ./datasets/chess/train/Pawn/Pawn68.png
# ./datasets/chess/train/Rook/Rook36.png
# ./datasets/chess/train/King/King55.png
# ./datasets/chess/train/Knight/Knight49.png
# ./datasets/chess/train/Rook/Rook39.png
# ./datasets/chess/train/Bishop/Bishop58.png
# ./datasets/chess/train/Pawn/Pawn93.png
# ./datasets/chess/train/Queen/Queen39.png
# ./datasets/chess/train/Knight/Knight66.png
# ./datasets/chess/train/Bishop/Bishop70.png
# ./datasets/chess/train/Knight/Knight88.png
# ./datasets/chess/train/Rook/Rook28.png
# ./datasets/chess/train/Bishop/Bishop22.png
# ./datasets/chess/train/Knight/Knight95.png
# ./datasets/chess/train/King/King72.png
# ./datasets/chess/train/Pawn/Pawn82.png
# ./datasets/chess/train/Knight/Knight43.png
# ./datasets/chess/train/Rook/Rook30.png
# ./datasets/chess/train/Queen/Queen9.png
# ./datasets/chess/train/Pawn/Pawn50.png
# ./datasets/chess/train/Knight/Knight63.png
# ./datasets/chess/train/Knight/Knight80.png
# ./datasets/chess/train/Pawn/Pawn20.png
# ./datasets/chess/train/Pawn/Pawn18.png
# ./datasets/chess/train/King/King24.png
# ./datasets/chess/train/King/King39.png
# ./datasets/chess/train/King/King73.png
# ./datasets/chess/train/King/King20.png
# ./datasets/chess/train/Knight/Knight34.png
# ./datasets/chess/train/Bishop/Bishop23.png
# ./datasets/chess/train/King/King40.png
# ./datasets/chess/train/Knight/Knight3.png
# ./datasets/chess/train/Knight/Knight70.png
# ./datasets/chess/train/Knight/Knight16.png
# ./datasets/chess/train/Knight/Knight45.png
# ./datasets/chess/train/Rook/Rook97.png
# ./datasets/chess/train/Rook/Rook43.png
# ./datasets/chess/train/Queen/Queen2.png
# ./datasets/chess/train/Bishop/Bishop84.png
#  1/23 ━━━━━━━━━━━━━━━━━━━━ 7:03 19s/step - acc: 0.2500 - loss: 1.6943./datasets/chess/train/Queen/Queen41.png
# ./datasets/chess/train/Rook/Rook7.png
# ./datasets/chess/train/King/King15.png
# ./datasets/chess/train/King/King2.png
# ./datasets/chess/train/Bishop/Bishop1.png
# ./datasets/chess/train/Knight/Knight76.png
# ./datasets/chess/train/Knight/Knight12.png
# ./datasets/chess/train/Pawn/Pawn105.png
# ./datasets/chess/train/Pawn/Pawn45.png
# ./datasets/chess/train/Bishop/Bishop3.png
# ./datasets/chess/train/King/King23.png
# ./datasets/chess/train/King/King29.png
# ./datasets/chess/train/Bishop/Bishop40.png
# ./datasets/chess/train/Pawn/Pawn98.png
# ./datasets/chess/train/Bishop/Bishop54.png
# ./datasets/chess/train/Bishop/Bishop73.png
#  2/23 ━━━━━━━━━━━━━━━━━━━━ 10s 499ms/step - acc: 0.2188 - loss: 1.7144./datasets/chess/train/Pawn/Pawn39.png
# ./datasets/chess/train/Knight/Knight36.png
# ./datasets/chess/train/Queen/Queen76.png
# ./datasets/chess/train/Rook/Rook101.png
# ./datasets/chess/train/Pawn/Pawn59.png
# ./datasets/chess/train/Pawn/Pawn79.png
# ./datasets/chess/train/Knight/Knight41.png
# ./datasets/chess/train/King/King37.png
# ./datasets/chess/train/Pawn/Pawn1.png
# ./datasets/chess/train/Knight/Knight9.png
# ./datasets/chess/train/Pawn/Pawn27.png
# ./datasets/chess/train/Queen/Queen36.png
# ./datasets/chess/train/Rook/Rook9.png
# ./datasets/chess/train/Queen/Queen55.png
# ./datasets/chess/train/Queen/Queen74.png
# ./datasets/chess/train/Bishop/Bishop11.png
#  3/23 ━━━━━━━━━━━━━━━━━━━━ 9s 478ms/step - acc: 0.1944 - loss: 1.7517 ./datasets/chess/train/Rook/Rook98.png
# ./datasets/chess/train/Bishop/Bishop24.png
# ./datasets/chess/train/Rook/Rook4.png
# ./datasets/chess/train/Pawn/Pawn86.png
# ./datasets/chess/train/Pawn/Pawn53.png
# ./datasets/chess/train/Knight/Knight89.png
# ./datasets/chess/train/King/King34.png
#  4/23 ━━━━━━━━━━━━━━━━━━━━ 9s 479ms/step - acc: 0.1810 - loss: 1.7767./datasets/chess/train/Bishop/Bishop21.png
# ./datasets/chess/train/Pawn/Pawn14.png
# ./datasets/chess/train/Knight/Knight60.png
# ./datasets/chess/train/Knight/Knight33.png
# ./datasets/chess/train/King/King49.png
# ./datasets/chess/train/Queen/Queen4.png
# ./datasets/chess/train/Pawn/Pawn69.png
# ./datasets/chess/train/Queen/Queen30.png
# ./datasets/chess/train/Rook/Rook66.png
# ./datasets/chess/train/Bishop/Bishop10.png
# ./datasets/chess/train/Pawn/Pawn15.png
# ./datasets/chess/train/King/King69.png
# ./datasets/chess/train/Knight/Knight83.png
# ./datasets/chess/train/King/King76.png
# ./datasets/chess/train/Bishop/Bishop15.png
# ./datasets/chess/train/Pawn/Pawn77.png
# ./datasets/chess/train/Pawn/Pawn72.png
# ./datasets/chess/train/King/King1.png
# ./datasets/chess/train/Rook/Rook62.png
# ./datasets/chess/train/Bishop/Bishop78.png
# ./datasets/chess/train/Bishop/Bishop4.png
# ./datasets/chess/train/Knight/Knight15.png
# ./datasets/chess/train/Rook/Rook69.png
# ./datasets/chess/train/Pawn/Pawn85.png
# ./datasets/chess/train/King/King50.png
# ./datasets/chess/train/Rook/Rook91.png
# ./datasets/chess/train/King/King4.png
#  5/23 ━━━━━━━━━━━━━━━━━━━━ 9s 523ms/step - acc: 0.1748 - loss: 1.7955./datasets/chess/train/Bishop/Bishop33.png
# ./datasets/chess/train/Knight/Knight17.png
# ./datasets/chess/train/Bishop/Bishop2.png
# ./datasets/chess/train/King/King35.png
# ./datasets/chess/train/Knight/Knight96.png
#  6/23 ━━━━━━━━━━━━━━━━━━━━ 8s 511ms/step - acc: 0.1700 - loss: 1.8055./datasets/chess/train/King/King54.png
# ./datasets/chess/train/Queen/Queen40.png
# ./datasets/chess/train/Bishop/Bishop31.png
# ./datasets/chess/train/Bishop/Bishop27.png
# ./datasets/chess/train/Pawn/Pawn80.png
# ./datasets/chess/train/Queen/Queen23.png
# ./datasets/chess/train/Bishop/Bishop61.png
# ./datasets/chess/train/Queen/Queen77.png
# ./datasets/chess/train/Queen/Queen37.png
# ./datasets/chess/train/Knight/Knight67.png
# ./datasets/chess/train/Rook/Rook52.png
# ./datasets/chess/train/Bishop/Bishop72.png
# ./datasets/chess/train/Pawn/Pawn81.png
# ./datasets/chess/train/Knight/Knight2.png
# ./datasets/chess/train/Queen/Queen78.png
# ./datasets/chess/train/Pawn/Pawn25.png
# ./datasets/chess/train/King/King19.png
# ./datasets/chess/train/Knight/Knight97.png
# ./datasets/chess/train/Rook/Rook21.png
# ./datasets/chess/train/Pawn/Pawn89.png
# ./datasets/chess/train/Bishop/Bishop81.png
# ./datasets/chess/train/King/King22.png
# ./datasets/chess/train/Knight/Knight65.png
# ./datasets/chess/train/Rook/Rook15.png
# ./datasets/chess/train/Bishop/Bishop52.png
# ./datasets/chess/train/Knight/Knight47.png
# ./datasets/chess/train/Rook/Rook59.png
#  7/23 ━━━━━━━━━━━━━━━━━━━━ 8s 525ms/step - acc: 0.1661 - loss: 1.8114./datasets/chess/train/Bishop/Bishop42.png
# ./datasets/chess/train/Bishop/Bishop86.png
# ./datasets/chess/train/Knight/Knight78.png
# ./datasets/chess/train/Rook/Rook5.png
# ./datasets/chess/train/Bishop/Bishop9.png
# ./datasets/chess/train/King/King44.png
# ./datasets/chess/train/Knight/Knight79.png
# ./datasets/chess/train/Pawn/Pawn57.png
# ./datasets/chess/train/Rook/Rook17.png
# ./datasets/chess/train/Pawn/Pawn47.png
# ./datasets/chess/train/Queen/Queen59.png
# ./datasets/chess/train/Bishop/Bishop12.png
# ./datasets/chess/train/King/King48.png
# ./datasets/chess/train/Rook/Rook19.png
# ./datasets/chess/train/Pawn/Pawn5.png
#  8/23 ━━━━━━━━━━━━━━━━━━━━ 7s 518ms/step - acc: 0.1649 - loss: 1.8149./datasets/chess/train/Rook/Rook13.png
# ./datasets/chess/train/Queen/Queen6.png
# ./datasets/chess/train/Queen/Queen8.png
# ./datasets/chess/train/Queen/Queen24.png
# ./datasets/chess/train/Queen/Queen52.png
# ./datasets/chess/train/Pawn/Pawn49.png
# ./datasets/chess/train/Queen/Queen20.png
# ./datasets/chess/train/Bishop/Bishop14.png
# ./datasets/chess/train/Queen/Queen27.png
# ./datasets/chess/train/Rook/Rook18.png
# ./datasets/chess/train/Pawn/Pawn44.png
# ./datasets/chess/train/Queen/Queen45.png
# ./datasets/chess/train/Pawn/Pawn6.png
# ./datasets/chess/train/Queen/Queen71.png
# ./datasets/chess/train/King/King59.png
# ./datasets/chess/train/Pawn/Pawn31.png
# ./datasets/chess/train/King/King62.png
# ./datasets/chess/train/Knight/Knight92.png
#  9/23 ━━━━━━━━━━━━━━━━━━━━ 7s 520ms/step - acc: 0.1666 - loss: 1.8170./datasets/chess/train/Knight/Knight75.png
# ./datasets/chess/train/Rook/Rook10.png
# ./datasets/chess/train/Bishop/Bishop45.png
# ./datasets/chess/train/Queen/Queen31.png
# ./datasets/chess/train/Queen/Queen15.png
# ./datasets/chess/train/Bishop/Bishop74.png
# ./datasets/chess/train/Pawn/Pawn76.png
# ./datasets/chess/train/Knight/Knight52.png
# ./datasets/chess/train/Rook/Rook2.png
# ./datasets/chess/train/Bishop/Bishop13.png
# ./datasets/chess/train/Bishop/Bishop34.png
# ./datasets/chess/train/Knight/Knight86.png
# ./datasets/chess/train/King/King57.png
# ./datasets/chess/train/King/King53.png
# ./datasets/chess/train/Bishop/Bishop46.png
# ./datasets/chess/train/Pawn/Pawn62.png
# 10/23 ━━━━━━━━━━━━━━━━━━━━ 6s 515ms/step - acc: 0.1681 - loss: 1.8183./datasets/chess/train/Bishop/Bishop83.png
# ./datasets/chess/train/King/King67.png
# ./datasets/chess/train/King/King36.png
# ./datasets/chess/train/Queen/Queen44.png
# ./datasets/chess/train/Pawn/Pawn40.png
# ./datasets/chess/train/Pawn/Pawn92.png
# ./datasets/chess/train/Knight/Knight74.png
# ./datasets/chess/train/Queen/Queen50.png
# ./datasets/chess/train/Rook/Rook38.png
# ./datasets/chess/train/King/King11.png
# ./datasets/chess/train/King/King17.png
# 12/23 ━━━━━━━━━━━━━━━━━━━━ 5s 511ms/step - acc: 0.1699 - loss: 1.8193./datasets/chess/train/King/King8.png
# ./datasets/chess/train/Rook/Rook95.png
# ./datasets/chess/train/Rook/Rook45.png
# ./datasets/chess/train/Rook/Rook76.png
# ./datasets/chess/train/Pawn/Pawn16.png
# ./datasets/chess/train/Knight/Knight22.png
# ./datasets/chess/train/Queen/Queen51.png
# ./datasets/chess/train/Rook/Rook8.png
# ./datasets/chess/train/King/King30.png
# ./datasets/chess/train/Queen/Queen65.png
# ./datasets/chess/train/King/King26.png
# ./datasets/chess/train/King/King58.png
# ./datasets/chess/train/Bishop/Bishop37.png
# ./datasets/chess/train/Knight/Knight26.png
# ./datasets/chess/train/King/King18.png
# ./datasets/chess/train/Queen/Queen46.png
# ./datasets/chess/train/Rook/Rook35.png
# ./datasets/chess/train/Queen/Queen48.png
# ./datasets/chess/train/Pawn/Pawn106.png
# ./datasets/chess/train/Queen/Queen32.png
# ./datasets/chess/train/Bishop/Bishop63.png
# ./datasets/chess/train/Pawn/Pawn52.png
# ./datasets/chess/train/Rook/Rook3.png
# ./datasets/chess/train/Queen/Queen57.png
# ./datasets/chess/train/Pawn/Pawn32.png
# ./datasets/chess/train/Rook/Rook26.png
# 13/23 ━━━━━━━━━━━━━━━━━━━━ 5s 516ms/step - acc: 0.1709 - loss: 1.8194./datasets/chess/train/Queen/Queen21.png
# ./datasets/chess/train/Pawn/Pawn70.png
# ./datasets/chess/train/Bishop/Bishop38.png
# ./datasets/chess/train/Bishop/Bishop75.png
# ./datasets/chess/train/Knight/Knight48.png
# ./datasets/chess/train/Rook/Rook20.png
# ./datasets/chess/train/Rook/Rook93.png
# ./datasets/chess/train/Pawn/Pawn83.png
# ./datasets/chess/train/Queen/Queen34.png
# ./datasets/chess/train/Rook/Rook27.png
# ./datasets/chess/train/Pawn/Pawn46.png
# ./datasets/chess/train/Knight/Knight104.png
# ./datasets/chess/train/Knight/Knight8.png
# 14/23 ━━━━━━━━━━━━━━━━━━━━ 4s 514ms/step - acc: 0.1708 - loss: 1.8194./datasets/chess/train/King/King42.png
# ./datasets/chess/train/King/King27.png
# 15/23 ━━━━━━━━━━━━━━━━━━━━ 4s 512ms/step - acc: 0.1708 - loss: 1.8192./datasets/chess/train/Rook/Rook65.png
# ./datasets/chess/train/Rook/Rook6.png
# ./datasets/chess/train/Knight/Knight77.png
# ./datasets/chess/train/Bishop/Bishop49.png
# ---------------------------------------------------------------------------
# UnknownError                              Traceback (most recent call last)
# Cell In[80], line 4
#       1 N_EPOCHS = 20
#       2 BATCH_SIZE = 16
# ----> 4 history = model.fit(train_dataset,
#       5                     batch_size=BATCH_SIZE,
#       6                     epochs=N_EPOCHS,
#       7                     validation_data=validation_dataset,
#       8                     callbacks=[mcp_cb, rlr_cb, ely_cb])
#
# File C:\ProgramData\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File C:\ProgramData\anaconda3\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# UnknownError: Graph execution error:
#
# Detected at node PyFunc defined at (most recent call last):
# <stack traces unavailable>
# error: OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:196: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# Traceback (most recent call last):
#
#   File "C:\ProgramData\anaconda3\Lib\site-packages\tensorflow\python\ops\script_ops.py", line 270, in __call__
#     ret = func(*args)
#           ^^^^^^^^^^^
#
#   File "C:\ProgramData\anaconda3\Lib\site-packages\tensorflow\python\autograph\impl\api.py", line 643, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#
#   File "C:\ProgramData\anaconda3\Lib\site-packages\tensorflow\python\data\ops\from_generator_op.py", line 198, in generator_py_func
#     values = next(generator_state.get_iterator(iterator_id))
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "C:\ProgramData\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py", line 260, in _get_iterator
#     for i, batch in enumerate(gen_fn()):
#
#   File "C:\ProgramData\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py", line 253, in generator_fn
#     yield self.py_dataset[i]
#           ~~~~~~~~~~~~~~~^^^
#
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_16504\2858089131.py", line 37, in __getitem__
#     image = cv2.cvtColor(cv2.imread(file_paths_batch[i]), cv2.COLOR_BGR2RGB)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# cv2.error: OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:196: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
#
#
# 	 [[{{node PyFunc}}]]
# 	 [[IteratorGetNext]] [Op:__inference_one_step_on_iterator_173679]
